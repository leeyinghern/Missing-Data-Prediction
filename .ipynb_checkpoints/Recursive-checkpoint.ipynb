# %%
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("https://gist.githubusercontent.com/tmramalho/51733432c88e2b834dbd70353849f887/raw/676636d9e8512963005a318cb9b98060feadb641/data.csv")

df.head()
# Out:
#       t                   x                   y
# 0  0.00                   -  0.5759052335487023
# 1  0.01                   -                   -
# 2  0.02  1.1159124144549086                   -
# 3  0.03                   -                   -
# 4  0.04  1.0054825084650338  0.4775267298487888

# %%
df['x'] = df['x'].apply(lambda x: np.nan if x == "-" else x)
df['y'] = df['y'].apply(lambda x: np.nan if x == "-" else x)

# %%
df.x = df.x.astype('float32')
df.y = df.y.astype('float32')
df
# Out:
#           t         x         y
# 0      0.00       NaN  0.575905
# 1      0.01       NaN       NaN
# 2      0.02  1.115912       NaN
# 3      0.03       NaN       NaN
# 4      0.04  1.005483  0.477527
# ...     ...       ...       ...
# 1995  19.95       NaN       NaN
# 1996  19.96       NaN       NaN
# 1997  19.97       NaN       NaN
# 1998  19.98  0.622993       NaN
# 1999  19.99  0.622504       NaN
#
# [2000 rows x 3 columns]

# %%
plt.figure(figsize=(20,10))
plt.plot(df['t'],df['x'], label="Prey")
plt.plot(df['t'],df['y'], label="Predator")
plt.legend();

# %%
df.dropna(inplace=True,thresh=3)
df
# Out:
#           t         x         y
# 4      0.04  1.005483  0.477527
# 6      0.06  1.101832  0.460175
# 13     0.13  1.020803  0.376706
# 18     0.18  1.165619  0.345918
# 30     0.30  1.161122  0.397953
# ...     ...       ...       ...
# 1968  19.68  0.973341  4.724112
# 1974  19.74  0.726388  4.360858
# 1980  19.80  0.737377  3.822630
# 1984  19.84  0.898905  4.297797
# 1987  19.87  0.809846  3.549376
#
# [327 rows x 3 columns]

# %%
HORIZON = 1
WINDOW_SIZE = 7

# %%
train = tf.keras.utils.timeseries_dataset_from_array(df[:int(0.8*len(df))]['t'], 
                                             df[:int(0.8*len(df))][['x','y']][WINDOW_SIZE::WINDOW_SIZE],
                                             sequence_length = WINDOW_SIZE,
                                            )
test = tf.keras.utils.timeseries_dataset_from_array(df[int(0.8*len(df)):]['t'], 
                                             df[int(0.8*len(df)):][['x','y']][WINDOW_SIZE::WINDOW_SIZE],
                                             sequence_length = WINDOW_SIZE,
                                            )

# %%
x_train = []
y_train = []
x_test = []
y_test = []

for batch in train:
    inputs, targets = batch
    x_train.append(inputs.numpy().tolist())
    y_train.append(targets.numpy().tolist())

for batch in test:
    inputs, targets = batch
    x_test.append(inputs.numpy().tolist())
    y_test.append(targets.numpy().tolist())

# %%
train = pd.DataFrame(x_train).T
train['sin'] = train[0].apply(lambda x: [np.sin(i) for i in x])
train['combined'] = train[0]+ train['sin']


test = pd.DataFrame(x_test).T
test['sin'] = test[0].apply(lambda x: [np.sin(i) for i in x])
test['combined'] = test[0]+ test['sin']

# %%
import os

def create_model_checkpoint(model_name, save_path="model_experiments"):
    return tf.keras.callbacks.ModelCheckpoint(filepath = os.path.join(save_path, model_name),
                                              verbose = 0,
                                              save_best_only=True
                                             )
lr_scheduler = tf.keras.callbacks.LearningRateScheduler(lambda epoch: 1e-4 * 10**(epoch/20))

# %%
from tensorflow.keras import layers
tf.random.set_seed(42)

model = tf.keras.Sequential()
model.add(layers.Dense(150, activation = "relu"))
model.add(layers.Dense(50, activation = "relu"))
model.add(layers.Dense(2, activation="linear"))

model.compile(loss=tf.keras.losses.mse,
              optimizer=tf.keras.optimizers.Adam(),
              metrics=[tf.keras.losses.mae,tf.keras.losses.mse]
             )

history = model.fit([[x for x in train.combined]], 
          y_train, 
          epochs = 500, 
          validation_data = ([[x for x in test.combined]], y_test),
          callbacks = [create_model_checkpoint("model_1"),lr_scheduler],
          batch_size = 32
         )
# Out:
# Epoch 1/500
# ...
# 1/1 [==============================] - 1s 896ms/step - loss: 8.6828 - mean_absolute_error: 1.8799 - mean_squared_error: 8.6828 - val_loss: 13.6779 - val_mean_absolute_error: 2.7526 - val_mean_squared_error: 13.6779 - lr: 1.0000e-04
# Epoch 2/500
# ...
# 1/1 [==============================] - 0s 384ms/step - loss: 8.6311 - mean_absolute_error: 1.8730 - mean_squared_error: 8.6311 - val_loss: 13.0902 - val_mean_absolute_error: 2.6986 - val_mean_squared_error: 13.0902 - lr: 1.1220e-04
# Epoch 3/500
# ...
# 1/1 [==============================] - 0s 374ms/step - loss: 8.5740 - mean_absolute_error: 1.8653 - mean_squared_error: 8.5740 - val_loss: 12.4800 - val_mean_absolute_error: 2.6378 - val_mean_squared_error: 12.4800 - lr: 1.2589e-04
# Epoch 4/500
# ...
# 1/1 [==============================] - 0s 375ms/step - loss: 8.5111 - mean_absolute_error: 1.8566 - mean_squared_error: 8.5111 - val_loss: 11.8592 - val_mean_absolute_error: 2.5771 - val_mean_squared_error: 11.8592 - lr: 1.4125e-04
# ...

# %%
perf = pd.DataFrame(history.history)
perf.loc[perf["val_loss"]==min(perf["val_loss"])]
# Out:
#        loss  mean_absolute_error  mean_squared_error  val_loss  \
# 9  8.017124             1.785873            8.017124  9.221018
#
#    val_mean_absolute_error  val_mean_squared_error        lr
# 9                 2.373154                9.221018  0.000282

# %%
from tensorflow.keras import layers
tf.random.set_seed(42)

model = tf.keras.Sequential()
model.add(layers.Dense(150, activation = "relu"))
model.add(layers.Dense(50, activation = "relu"))
model.add(layers.Dense(20, activation = "relu"))
model.add(layers.Dense(2, activation="linear"))

model.compile(loss=tf.keras.losses.mse,
              optimizer=tf.keras.optimizers.Adam(learning_rate = 0.000282),
              metrics=[tf.keras.losses.mae,tf.keras.losses.mse]
             )

history = model.fit([[x for x in train.combined]], 
          y_train, 
          epochs = 500, 
          validation_data = ([[x for x in test.combined]], y_test),
          callbacks = [create_model_checkpoint("model_1")],
          batch_size = 32
         )
# Out:
# Epoch 1/500
# ...
# 1/1 [==============================] - 1s 1s/step - loss: 9.9458 - mean_absolute_error: 2.0912 - mean_squared_error: 9.9458 - val_loss: 25.9758 - val_mean_absolute_error: 4.2017 - val_mean_squared_error: 25.9758
# Epoch 2/500
# ...
# 1/1 [==============================] - 0s 461ms/step - loss: 9.8174 - mean_absolute_error: 2.0685 - mean_squared_error: 9.8174 - val_loss: 24.4672 - val_mean_absolute_error: 4.0581 - val_mean_squared_error: 24.4672
# Epoch 3/500
# ...
# 1/1 [==============================] - 0s 455ms/step - loss: 9.6877 - mean_absolute_error: 2.0449 - mean_squared_error: 9.6877 - val_loss: 23.1525 - val_mean_absolute_error: 3.9226 - val_mean_squared_error: 23.1525
# Epoch 4/500
# ...
# 1/1 [==============================] - 0s 451ms/step - loss: 9.5603 - mean_absolute_error: 2.0207 - mean_squared_error: 9.5603 - val_loss: 21.8935 - val_mean_absolute_error: 3.7931 - val_mean_squared_error: 21.8935
# Epoch 5/500
# ...

# %%
train_pred = model.predict([[x for x in train.combined]])
test_pred = model.predict([[x for x in test.combined]])

# %%
test_pred
# Out:
# array([[[ 15.510895 , -11.932782 ],
#         [ 15.578968 , -12.001737 ],
#         [ 15.6765585, -12.110736 ],
#         [ 15.795447 , -12.222798 ],
#         [ 15.922804 , -12.351407 ],
#         [ 16.031378 , -12.459023 ],
#         [ 16.197632 , -12.615416 ],
#         [ 16.291058 , -12.699227 ],
#         [ 16.37061  , -12.764866 ]]], dtype=float32)

# %%
y_test
# Out:
# [[[3.416645050048828, 0.0842946320772171],
#   [4.824976921081543, 0.10249858349561691],
#   [4.946194171905518, 0.15198484063148499],
#   [6.077707767486572, 0.28082534670829773],
#   [8.190402030944824, 1.1127142906188965],
#   [6.780978679656982, 3.480677604675293],
#   [3.8877532482147217, 9.220382690429688],
#   [1.7781425714492798, 9.206892013549805],
#   [0.7373766303062439, 3.822629928588867]]]

# %%
model.evaluate([[x for x in test.combined]], y_test)
# Out:
# 1/1 [==============================] - 0s 17ms/step - loss: 193.7905 - mean_absolute_error: 13.4087 - mean_squared_error: 193.7905
# [193.79052734375, 13.408670425415039, 193.79052734375]

# %%
model = tf.keras.models.load_model("model_experiments/model_1/")
model.evaluate([[x for x in test.combined]], y_test)
# Out:
# 1/1 [==============================] - 0s 89ms/step - loss: 8.8029 - mean_absolute_error: 2.4147 - mean_squared_error: 8.8029
# [8.802858352661133, 2.414663314819336, 8.802858352661133]

# %%
test_pred = model.predict([[x for x in test.combined]])

# %%
test_pred
# Out:
# array([[[4.5441613, 3.0615654],
#         [4.542935 , 3.0674243],
#         [4.5478487, 3.0335708],
#         [4.5522246, 3.0536346],
#         [4.5564885, 3.0596128],
#         [4.5611515, 3.0733275],
#         [4.574586 , 3.0829432],
#         [4.5952663, 3.102353 ],
#         [4.61622  , 3.121436 ]]], dtype=float32)

# %%
y_test
# Out:
# [[[3.416645050048828, 0.0842946320772171],
#   [4.824976921081543, 0.10249858349561691],
#   [4.946194171905518, 0.15198484063148499],
#   [6.077707767486572, 0.28082534670829773],
#   [8.190402030944824, 1.1127142906188965],
#   [6.780978679656982, 3.480677604675293],
#   [3.8877532482147217, 9.220382690429688],
#   [1.7781425714492798, 9.206892013549805],
#   [0.7373766303062439, 3.822629928588867]]]
